# %% [markdown]
# ### Preparación de ambiente

# %% [markdown]
# #### Lectura de archivos desde S3

# %%
# !pip3 install boto3

# %%
import os

import boto3
import pandas as pd


AWS_S3_BUCKET = "g6-datalake-proyectointegrador"
AWS_ACCESS_KEY_ID = "ASIA3T2YJ54QMMRGILWT"
AWS_SECRET_ACCESS_KEY = "Dr8iICRJJk9aJi8atKj0nLJXJRh/qtfTf8ugSX8f"
AWS_SESSION_TOKEN = ""

s3_client = boto3.client(
    "s3",
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    aws_session_token=AWS_SESSION_TOKEN,
)

response = s3_client.get_object(Bucket=AWS_S3_BUCKET, Key="03_TrustedZone/03_BaseFormuladaLimpia.csv")

status = response.get("ResponseMetadata", {}).get("HTTPStatusCode")

if status == 200:
    print(f"Successful S3 get_object response. Status - {status}")
    base_formulada = pd.read_csv(response.get("Body"), encoding='UTF-8')
    #print(df)
else:
    print(f"Unsuccessful S3 get_object response. Status - {status}")


response1 = s3_client.get_object(Bucket=AWS_S3_BUCKET, Key="03_TrustedZone/03_ServCompLimpiada.csv")

status = response1.get("ResponseMetadata", {}).get("HTTPStatusCode")

if status == 200:
    print(f"Successful S3 get_object response. Status - {status}")
    serv_com = pd.read_csv(response1.get("Body"), encoding='UTF-8')
    #print(df)
else:
    print(f"Unsuccessful S3 get_object response. Status - {status}")
# Out:
# Successful S3 get_object response. Status - 200
# Successful S3 get_object response. Status - 200
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import pandas as pd

# %%
base_formulada.columns
# Out:
# Index(['Unnamed: 0', 'codinmueble', 'codproyecto', 'codvende', 'estrato',
#        'area', 'alc.', 'baños', 'area patio', 'area lote / jardin',
#        'area terraza o balcon', 'estudio/estar', 'c y b serv.', 'depósito',
#        'añomes', 'precio', 'inflacion', 'precio_deflacionado',
#        'zona_Med. No VIS', 'zona_Med. No Vis', 'zona_Med. VIS',
#        'zona_Med. Vis', 'zona_Norte No VIS', 'zona_Norte VIS',
#        'zona_Occidente VIS', 'zona_Oriente No VIS', 'zona_Oriente VIS',
#        'zona_Sur No VIS', 'zona_Sur VIS', 'sub zona_Belén',
#        'sub zona_Buenos Aires', 'sub zona_Caldas', 'sub zona_Copacabana',
#        'sub zona_El Carmen de Viboral', 'sub zona_El Poblado',
#        'sub zona_El Retiro', 'sub zona_Envigado', 'sub zona_Girardota',
#        'sub zona_Guarne', 'sub zona_Guayabal', 'sub zona_Itagüí',
#        'sub zona_La América', 'sub zona_La Candelaria', 'sub zona_La Ceja',
#        'sub zona_La Estrella', 'sub zona_Laureles Estadio',
# ...

# %%
serv_com.columns
# Out:
# Index(['Codproyecto', 'Proyecto', 'Zona', 'Coc. Integral', 'Extractor',
#        'Lav-Sec', 'Estufa', 'Horno', 'Calentador', 'Chimeneas', 'Tinas',
#        'Depósito', 'Portería', 'Salón Social', 'Parque Inf.', 'Planta Eléct.',
#        'Shut Basuras', 'No. Ascensores x Torre', 'Tipo Urbanizacion',
#        'Tipo Est.', 'Vent.', 'Muros Bañ.', 'Activo', 'AñoMesU',
#        'Gimnasio_Biosaludable', 'Gimnasio_Dotado', 'Gimnasio_Espacio',
#        'Ofrece Piscina_Comunal', 'Ofrece Piscina_Privada', 'Saunas_Jacuzzi',
#        'Saunas_Sauna', 'Saunas_Turco'],
#       dtype='object')

# %%
serv_com['codproyecto'] = serv_com['Codproyecto']
serv_com = serv_com.drop(['Codproyecto','Zona','Proyecto','AñoMesU','Gimnasio_Biosaludable','No. Ascensores x Torre','Salón Social'],axis=1)
serv_com = serv_com.drop_duplicates()
base_formulada = base_formulada.drop(['Unnamed: 0','codinmueble','codvende'],axis=1)
base_formulada = base_formulada.drop_duplicates()

# %%
df = pd.merge(base_formulada, serv_com, on='codproyecto', how='inner')

# %%
df
# Out:
#         codproyecto  estrato   area  alc.  baños  area patio  \
# 0             60000      6.0  301.0   3.0    4.0         0.0
# 1             60000      6.0  301.0   3.0    4.0         0.0
# 2             60000      6.0  301.0   3.0    4.0         0.0
# 3             60000      6.0  301.0   3.0    4.0         0.0
# 4             60000      6.0  301.0   3.0    4.0         0.0
# ...             ...      ...    ...   ...    ...         ...
# 709334        62192      4.0   72.0   2.0    2.0         0.0
# 709335        62192      4.0   72.0   2.0    2.0         0.0
# 709336        62192      4.0   67.0   3.0    2.0         0.0
# 709337        62192      4.0   67.0   3.0    2.0         0.0
# 709338        62192      4.0   67.0   3.0    2.0         0.0
#
#         area lote / jardin  area terraza o balcon  estudio/estar  c y b serv.  \
# 0                      0.0                   14.0              1            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 709339 entries, 0 to 709338
# Data columns (total 97 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   codproyecto                               709339 non-null  int64
#  1   estrato                                   709339 non-null  float64
#  2   area                                      709339 non-null  float64
#  3   alc.                                      709339 non-null  float64
#  4   baños                                     709339 non-null  float64
#  5   area patio                                709339 non-null  float64
#  6   area lote / jardin                        709339 non-null  float64
#  7   area terraza o balcon                     709339 non-null  float64
#  8   estudio/estar                             709339 non-null  int64
#  9   c y b serv.                               709339 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['codproyecto', 'estrato', 'area', 'alc.', 'baños', 'area patio',
#        'area lote / jardin', 'area terraza o balcon', 'estudio/estar',
#        'c y b serv.', 'depósito', 'añomes', 'precio', 'inflacion',
#        'precio_deflacionado', 'zona_Med. No VIS', 'zona_Med. No Vis',
#        'zona_Med. VIS', 'zona_Med. Vis', 'zona_Norte No VIS', 'zona_Norte VIS',
#        'zona_Occidente VIS', 'zona_Oriente No VIS', 'zona_Oriente VIS',
#        'zona_Sur No VIS', 'zona_Sur VIS', 'sub zona_Belén',
#        'sub zona_Buenos Aires', 'sub zona_Caldas', 'sub zona_Copacabana',
#        'sub zona_El Carmen de Viboral', 'sub zona_El Poblado',
#        'sub zona_El Retiro', 'sub zona_Envigado', 'sub zona_Girardota',
#        'sub zona_Guarne', 'sub zona_Guayabal', 'sub zona_Itagüí',
#        'sub zona_La América', 'sub zona_La Candelaria', 'sub zona_La Ceja',
#        'sub zona_La Estrella', 'sub zona_Laureles Estadio',
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 709339 entries, 0 to 709338
# Data columns (total 97 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   codproyecto                               709339 non-null  int64
#  1   estrato                                   709339 non-null  float64
#  2   area                                      709339 non-null  float64
#  3   alc.                                      709339 non-null  float64
#  4   baños                                     709339 non-null  float64
#  5   area patio                                709339 non-null  float64
#  6   area lote / jardin                        709339 non-null  float64
#  7   area terraza o balcon                     709339 non-null  float64
#  8   estudio/estar                             709339 non-null  int64
#  9   c y b serv.                               709339 non-null  int64
# ...

# %%
df.to_csv(r"C:\Users\ALEJANDRO RENDON\OneDrive\EAFIT\1 semestre\PI1\TablaUnida.csv")
